# %%
import time
from urllib.parse import quote
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import uuid 
import requests
from sqlalchemy import create_engine
import math

# %%
def generate_header(key = '数据分析', city = '全国'):
    header = {'Host': 'www.lagou.com',
              'Origin': 'https://www.lagou.com',
              #https://www.lagou.com/jobs/list_%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90?px=new&city=%E5%85%A8%E5%9B%BD
               'Referer': 'https://www.lagou.com/jobs/list_{}?px=new&city={}'.format(quote(key),quote(city)),
               'Cookie' :'user_trace_token=20180314163431-b3a5992f-95ac-4cdb-84bd-8f86a5e084ad; _ga=GA1.2.521321231.1521016472; LGUID=20180314163432-84e6251a-2762-11e8-b1e3-5254005c3644; index_location_city=%E5%85%A8%E5%9B%BD; JSESSIONID=ABAAABAAAGGABCBD6CF3DF428E3511D25B9B7FB773F7B0E; X_HTTP_TOKEN=b9e62565f65403103924971a79b26efc; LGSID=20180412142155-cc1251f6-3e19-11e8-b747-5254005c3644; LGRID=20180412142622-6b0de44c-3e1a-11e8-ba22-525400f775ce; TG-TRACK-CODE=search_code; SEARCH_ID=231099152a164535b75106a7c3de1c7f',
              'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36'
               }
    return header

# %%
#cookie = {'JSESSIONID': 'ABAAABAAAGGABCBD6CF3DF428E3511D25B9B7FB773F7B0E',
           '_gat': '1',
           'user_trace_token': '20180314163431-b3a5992f-95ac-4cdb-84bd-8f86a5e084ad',
           'PRE_UTM': '',
           'PRE_HOST': '',
           'PRE_SITE': '',
           'PRE_LAND': 'https%3A%2F%2Fwww.lagou.com%2F',
           'LGUID': '20180314163432-84e6251a-2762-11e8-b1e3-5254005c3644',
           'SEARCH_ID': 'a7eabf5cad164281999a3f8aea9ccbf6',           
           '_ga': 'GA1.2.2003702965.1486066203',
           'LGSID': '20180412084817-30b63808-3deb-11e8-b9e2-525400f775ce',
           'LGRID': '20180412084817-30b63808-3deb-11e8-b9e2-525400f775ce'}

# %%
#import uuidimport requests
#def get_uuid():
    return str(uuid.uuid4())
cookie = "JSESSIONID=" + get_uuid() + ";" "user_trace_token=" + get_uuid() + "; LGUID=" + get_uuid() + "; index_location_city=%E6%88%90%E9%83%BD; " \
"SEARCH_ID=" + get_uuid() + '; _gid=GA1.2.717841549.1514043316; ' \
'_ga=GA1.2.952298646.1514043316; ' \
'LGSID=' + get_uuid() + "; " \
"LGRID=" + get_uuid() + "; "
headers = {'cookie': cookie,
           'origin': "https://www.lagou.com",
           'x-anit-forge-code': "0",
           'accept-encoding': "gzip, deflate, br",
           'accept-language': "zh-CN,zh;q=0.8,en;q=0.6",
           'user-agent': "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36",
           'content-type': "application/x-www-form-urlencoded; charset=UTF-8",
           'accept': "application/json, text/javascript, */*; q=0.01",
           'referer': "https://www.lagou.com/jobs/list_Java?px=new&city=%E6%88%90%E9%83%BD",
           'x-requested-with': "XMLHttpRequest",'connection': "keep-alive",
           'x-anit-forge-token': "None",
           'cache-control': "no-cache",
           'postman-token': "91beb456-8dd9-0390-a3a5-64ff3936fa63"

# %%
def request_url(offset):
    #https://www.lagou.com/jobs/positionAjax.json?needAddtionalResult=false
    #https://www.lagou.com/jobs/positionAjax.json?px=default&city=%E4%B8%8A%E6%B5%B7&needAddtionalResult=false
    header = generate_header()
    url = "https://www.lagou.com/jobs/positionAjax.json"
    payload = {'px': 'new',
               'needAddtionalResult': 'false',
               'city':'全国'
               }
    formdata = {'first': 'false',
                'pn': offset,
                'kd': '数据分析'
                }
    try:
        response = requests.request("POST", url, data=formdata, params=payload, headers=header,timeout=10)
        if response.status_code == 200:
            return response.json()
    except Exception as e:
        print("Brief Info Exception: {}".format(e))

# %%
request_url(1)
# Out:
# {'code': 0,
#  'content': {'hrInfoMap': {'1845914': {'canTalk': True,
#     'phone': None,
#     'portrait': None,
#     'positionName': 'HR',
#     'realName': 'Scarlett',
#     'receiveEmail': None,
#     'userId': 1447251,
#     'userLevel': 'G1'},
#    '2353221': {'canTalk': True,
#     'phone': None,
#     'portrait': None,
#     'positionName': '',
#     'realName': 'hr.xa',
#     'receiveEmail': None,
#     'userId': 4279742,
#     'userLevel': 'G1'},
#    '2716397': {'canTalk': True,
#     'phone': None,
#     'portrait': None,
#     'positionName': None,
#     'realName': 'career',
#     'receiveEmail': None,
#     'userId': 6048668,
#     'userLevel': 'G1'},
#    '2744665': {'canTalk': True,
#     'phone': None,
#     'portrait': None,
#     'positionName': '高级人力资源经理',
#     'realName': '悠易互通HR',
#     'receiveEmail': None,
#     'userId': 589805,
#     'userLevel': 'G1'},
#    '3586368': {'canTalk': True,
#     'phone': None,
#     'portrait': None,
# ...

# %%
#单个职位jd提取
def get_descriptions(positionid):
    url = 'https://www.lagou.com/jobs/{}.html'.format(positionid)
    header = generate_header()
    response = requests.get(url, headers=header,timeout=10)
    try:
        if response.status_code == 200:
            html_code = response.text
            soup = BeautifulSoup(html_code, 'lxml')
        jd = soup.select('#job_detail > dd.job_bt > div',)
        #jd = job_detail = soup.select('#job_detail > dd.job_bt ',)                 
        content = jd[0].get_text()
        content_clean = "".join(content.split())
    except Exception as e:
        print("Jd Exception: {}".format(e))
    return content_clean

# %%
#单个职位所有信息提取
def getdetail(result): 
    #信息提取
    df = pd.DataFrame()
    data = result['content']['positionResult'] 
    infos = data['result']      
    for info in infos:    
        #
        df_item = pd.DataFrame.from_dict(info, orient='index').transpose()
        #
        df_item['content'] = get_descriptions(info['positionId'])
        df =df.append(df_item)  
        time.sleep(3)
    return df

# %%
def save_sql(df,tablename):
    #打开数据库存储数据
    engine = create_engine('postgresql://postgres:947172@localhost:5432/postgres') 
    #create_engine说明：dialect[+driver]://user:password@host/dbname[?key=value..]
    try:
        df.to_sql(tablename,engine,index=False,if_exists='append')
        #conn = psycopg2.connect(database="platoon", user="postgres", password="postgres", 
                           # host="192.168.10.80",port="5432")
        #数据库游标
        #cur=conn.cursor()  
        print ('数据存储成功' )  
    except Exception as e:
        print("Sql Exception: {}".format(e))

# %%
def main(offset):
    positioninfo = getdetail(request_url(offset))
    print('第{}页爬取成功'.format(offset))
    save_sql(positioninfo,"lagou0412v5")
    time.sleep(3)

# %%
if __name__ == '__main__':
    try:
        pageCount = math.ceil(request_url(1)['content']['positionResult']['totalCount']/15)
        print('共{0}页'.format(pageCount))
        for page in range(1,pageCount+1):
               main(page)
    except Exception as e:
        print("Page Exception: {}".format(e))
# Out:
# 共206页
# 第1页爬取成功
# 数据存储成功
# 第2页爬取成功
# 数据存储成功
# 第3页爬取成功
# 数据存储成功
# 第4页爬取成功
# 数据存储成功
# 第5页爬取成功
# 数据存储成功
# 第6页爬取成功
# 数据存储成功
# 第7页爬取成功
# 数据存储成功
# 第8页爬取成功
# 数据存储成功
# 第9页爬取成功
# 数据存储成功
# 第10页爬取成功
# 数据存储成功
# 第11页爬取成功
# 数据存储成功
# 第12页爬取成功
# 数据存储成功
# 第13页爬取成功
# 数据存储成功
# 第14页爬取成功
# 数据存储成功
# 第15页爬取成功
# 数据存储成功
# 第16页爬取成功
# 数据存储成功
# 第17页爬取成功
# 数据存储成功
# 第18页爬取成功
# 数据存储成功
# 第19页爬取成功
# 数据存储成功
# 第20页爬取成功
# 数据存储成功
# 第21页爬取成功
# 数据存储成功
# 第22页爬取成功
# 数据存储成功
# 第23页爬取成功
# 数据存储成功
# 第24页爬取成功
# 数据存储成功
# 第25页爬取成功
# 数据存储成功
# 第26页爬取成功
# 数据存储成功
# 第27页爬取成功
# 数据存储成功
# 第28页爬取成功
# 数据存储成功
# 第29页爬取成功
# 数据存储成功
# 第30页爬取成功
# 数据存储成功
# 第31页爬取成功
# 数据存储成功
# 第32页爬取成功
# 数据存储成功
# 第33页爬取成功
# 数据存储成功
# 第34页爬取成功
# 数据存储成功
# 第35页爬取成功
# 数据存储成功
# 第36页爬取成功
# 数据存储成功
# 第37页爬取成功
# 数据存储成功
# 第38页爬取成功
# 数据存储成功
# 第39页爬取成功
# 数据存储成功
# 第40页爬取成功
# 数据存储成功
# 第41页爬取成功
# 数据存储成功
# 第42页爬取成功
# 数据存储成功
# 第43页爬取成功
# 数据存储成功
# 第44页爬取成功
# 数据存储成功
# 第45页爬取成功
# 数据存储成功
# 第46页爬取成功
# 数据存储成功
# 第47页爬取成功
# 数据存储成功
# 第48页爬取成功
# 数据存储成功
# 第49页爬取成功
# 数据存储成功
# 第50页爬取成功
# 数据存储成功
# ...

# %%
if __name__ == '__main__':
    try:
        pageCount = math.ceil(request_url(1)['content']['positionResult']['totalCount']/15)
        print('共{0}页'.format(pageCount))
        for page in range(192,pageCount+1):
               main(page)
    except Exception as e:
        print("Page Exception: {}".format(e))
# Out:
# 共208页
# 第192页爬取成功
# 数据存储成功
# 第193页爬取成功
# 数据存储成功
# 第194页爬取成功
# 数据存储成功
# 第195页爬取成功
# 数据存储成功
# 第196页爬取成功
# 数据存储成功
# 第197页爬取成功
# 数据存储成功
# 第198页爬取成功
# 数据存储成功
# 第199页爬取成功
# 数据存储成功
# 第200页爬取成功
# 数据存储成功
# 第201页爬取成功
# 数据存储成功
# 第202页爬取成功
# 数据存储成功
# 第203页爬取成功
# 数据存储成功
# 第204页爬取成功
# 数据存储成功
# 第205页爬取成功
# 数据存储成功
# 第206页爬取成功
# 数据存储成功
# 第207页爬取成功
# 数据存储成功
# 第208页爬取成功
# 数据存储成功

# %%
if __name__ == '__main__':
    pageCount = math.ceil(request_url(1)['content']['positionResult']['totalCount']/15)
    print('共{}页'.format(pageCount))
    queue = list(range(1,pageCount+1))  #构造一个简单的队列，起始是1        
    while len(queue):  # 队列还有就执行
        page_num = queue.pop(0)  # 取出队列的第一个
        try:
            main(page_num)    
        except Exception as e:
            print("Exception: {}".format(e))
            queue.append(page_num)# 出错放回到队列尾部
            time.sleep(10)

# %%
'adWord': 0,
 'appShow': 0,
 'approve': 1,
 'businessZones': None,
 'city': '广州',
 'companyFullName': '广州多益网络股份有限公司',
 'companyId': 589,
 'companyLabelList': ['扁平化管理', '现象级产品'],
 'companyLogo': 'i/image/M00/65/52/CgqKkVgHN3GAF78OAAQIwX6Cd-I564.png',
 'companyShortName': '多益网络',
 'companySize': '500-2000人',
 'createTime': '2018-04-11 20:33:35',
 'deliver': 0,
 'district': '萝岗区',
 'education': '大专',
 'explain': None,
 'financeStage': '不需要融资',
 'firstType': '开发/测试/运维类',
 'formatCreateTime': '20:33发布',
 'gradeDescription': None,
 'hitags': None,
 'imState': 'today',
 'industryField': '移动互联网,游戏',
 'industryLables': [],
 'isSchoolJob': 0,
 'jobNature': '全职',
 'lastLogin': 1523460467000,
 'latitude': '23.161058',
 'linestaion': None,
 'longitude': '113.505122',
 'pcShow': 0,
 'plus': None,
 'positionAdvantage': '平台,团队',
 'positionId': 4269582,
 'positionLables': [],
 'positionName': 'Python爬虫研发工程师',
 'promotionScoreExplain': None,
 'publisherId': 2548,
 'resumeProcessDay': 1,
 'resumeProcessRate': 95,
 'salary': '9k-15k',
 'score': 0,
 'secondType': '后端开发',
 'stationname': None,
 'subwayline': None,
 'workYear': '1-3年'}

# %%
position_list = pd.DataFrame()
#response = requests.post(url, data=para, headers=headers, cookies=cookies)
#result = response.json()
data = a['content']['positionResult']
#page_no = result['content']['pageNo']
infos = data['result']      

for info in infos:
    position = pd.Series()
    companyLabelList = info['companyLabelList']     # 职位诱惑(list)
    if len(companyLabelList) > 1:
        companyLabelList = '-'.join(companyLabelList)
    elif len(companyLabelList) == 1:
        companyLabelList = str(companyLabelList[0])
    else:
        companyLabelList = '-'
    positionLables = info['positionLables']         # 岗位技术标签(list)
    if len(positionLables) > 1:
        positionLables = '-'.join(positionLables)
    elif len(positionLables) == 1:
        positionLables = str(positionLables[0])
    else:
        positionLables = '-'
    position['positionId'] = info['positionId']                 # 职位ID
    position['positionName'] = info['positionName']             # 职位名称
    position['salary'] = info['salary']                         # 薪水
    position['education'] = info['education']                   # 学历要求
    position['workYear'] = info['workYear']                     # 工作经验要求
    position['positionLables'] = info['positionLables']         # 职位标签    
    position['jobNature'] = info['jobNature']                   # 全职/兼职
    position['positionAdvantage'] = info['positionAdvantage']   # 职位优势
    position['createTime'] = info['createTime']                 # 创建时间
    
    position['companyId'] = info['companyId']                   # 公司ID
    position['companyFullName'] = info['companyFullName']       # 公司全称
    position['companyShortName'] = info['companyShortName']     # 公司简称
    position['companyLabelList'] = info['companyLabelList']     # 公司标签
    position['industryField'] = info['industryField']           # 公司所属行业
    position['city'] = info['city']                             # 公司地点
    position['district'] = info['district']                     # 公司所属区
    position['companySize'] = info['companySize']               # 公司规模
    
    position['financeStage'] = info['financeStage']             # 公司融资规模
  
    position['firstType'] = info['firstType']                   # 第一岗位类型
    position['secondType'] = info['secondType']                 # 第二岗位类型
   
    position['latitude'] = info['latitude']                     # 纬度
    position['longitude'] = info['longitude']                   # 经度
            
    position = pd.DataFrame(position).T
    position_list = position_list.append(position)#单个商品单个评论页数据提取，存储函数

# %%
info
# Out:
# {'adWord': 0,
#  'appShow': 0,
#  'approve': 1,
#  'businessZones': None,
#  'city': '广州',
#  'companyFullName': '广州多益网络股份有限公司',
#  'companyId': 589,
#  'companyLabelList': ['扁平化管理', '现象级产品'],
#  'companyLogo': 'i/image/M00/65/52/CgqKkVgHN3GAF78OAAQIwX6Cd-I564.png',
#  'companyShortName': '多益网络',
#  'companySize': '500-2000人',
#  'createTime': '2018-04-11 20:33:35',
#  'deliver': 0,
#  'district': '萝岗区',
#  'education': '大专',
#  'explain': None,
#  'financeStage': '不需要融资',
#  'firstType': '开发/测试/运维类',
#  'formatCreateTime': '20:33发布',
#  'gradeDescription': None,
#  'hitags': None,
#  'imState': 'today',
#  'industryField': '移动互联网,游戏',
#  'industryLables': [],
#  'isSchoolJob': 0,
#  'jobNature': '全职',
#  'lastLogin': 1523460467000,
#  'latitude': '23.161058',
#  'linestaion': None,
#  'longitude': '113.505122',
#  'pcShow': 0,
#  'plus': None,
#  'positionAdvantage': '平台,团队',
#  'positionId': 4269582,
#  'positionLables': [],
#  'positionName': 'Python爬虫研发工程师',
# ...

# %%
def lagou_spider(result):
    """
    提交表单至url，获取返回的json格式的数据
    对数据进行清洗并返回
    """
    #url = 'https://www.lagou.com/jobs/positionAjax.json'
    
    #para = {'first': 'false', 'pn': '1', 'kd': keyword, 'city': city}
    position_list = pd.DataFrame()
    #response = requests.post(url, data=para, headers=headers, cookies=cookies)
    #result = response.json()
    data = result['content']['positionResult']
    #page_no = result['content']['pageNo']
    infos = data['result']
    for info in infos:
        position = pd.DataFrame()
        companyLabelList = info['companyLabelList']     # 职位诱惑(list)
        if len(companyLabelList) > 1:
            companyLabelList = '-'.join(companyLabelList)
        elif len(companyLabelList) == 1:
            companyLabelList = str(companyLabelList[0])
        else:
            companyLabelList = '-'
        positionLables = info['positionLables']         # 岗位技术标签(list)
        if len(positionLables) > 1:
            positionLables = '-'.join(positionLables)
        elif len(positionLables) == 1:
            positionLables = str(positionLables[0])
        else:
            positionLables = '-'
        position['positionId'] = info['positionId']                 # 职位ID
        position['positionName'] = info['positionName']             # 职位名称
        position['companyId'] = info['companyId']                   # 公司ID
        position['companyFullName'] = info['companyFullName']       # 公司全称
        position['companyShortName'] = info['companyShortName']     # 公司简称
        position['industryField'] = info['industryField']           # 公司所属行业
        position['city'] = info['city']                             # 公司地点
        position['companySize'] = info['companySize']               # 公司规模
        position['education'] = info['education']                   # 学历要求
        position['financeStage'] = info['financeStage']             # 公司融资规模
        position['salary'] = info['salary']                         # 薪水
        position['firstType'] = info['firstType']                   # 第一岗位类型
        position['secondType'] = info['secondType']                 # 第二岗位类型
        position['workYear'] = info['workYear']                     # 工作经验要求
        position['latitude'] = info['latitude']                     # 纬度
        position['longitude'] = info['longitude']                   # 经度
        position_list.append(position)

    #print("爬取第%s页成功,  %s" % (i, page_no))
    time.sleep(numpy.random.rand()*15)
    return position_list

# %%
def save_sql():
    #打开数据库存储数据
    #engine = create_engine('postgresql://postgres:947172@localhost:5432/postgres') 
    #create_engine说明：dialect[+driver]://user:password@host/dbname[?key=value..]
    try:
        #df.to_sql(tablename,engine,index=False,if_exists='append')
        conn = psycopg2.connect(database="postgres", user="postgres", password="947172", 
                                host="localhost",port="5432")
        #数据库游标
        cur=conn.cursor()  
        #建立表
        cur.execute('''CREATE TABLE lagou(
                        positionId int,
                        positionName varchar,    
                        companyId  int,       
                        companyFullName  varchar,
                        companyShortName varchar,
                        industryField varchar,
                        city varchar,
                        companySize varchar,
                        education varchar,       
                        financeStage varchar,
                        salary varchar,
                        firstType varchar,
                        secondType varchar,
                        workYear varchar,
                        latitude varchar,
                        longitude varchar,
                        PRIMARY KEY(positionId)
                    )''')
        
        cur.execute('''INSERT INTO lagou(positionId,
                                            positionName,
                                            companyIdt,
                                            companyFullName,
                                            companyShortName,
                                            industryField,city,
                                            companySize,
                                            education,       
                                            financeStage,
                                            salary,
                                            firstType,
                                            secondType,
                                            workYear,
                                            latitude,
                                            longitude)
                        VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)''',
                                        (positionId,
                                            positionName,
                                            companyIdt,
                                            companyFullName,
                                            companyShortName,
                                            industryField,city,
                                            companySize,
                                            education,       
                                            financeStage,
                                            salary,
                                            firstType,
                                            secondType,
                                            workYear,
                                            latitude,
                                            longitude))
        
        

    except Exception as e:
        print(e)
    conn.commit()
    cur.close()
    conn.close()
        
#getcomment(c).transpose()
